# %% [markdown]
# <a href="https://colab.research.google.com/github/acewolfag/modelFaceNet/blob/main/Face_Pytorch30/10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

rawatjitesh_avengers_face_recognition_path = kagglehub.dataset_download('rawatjitesh/avengers-face-recognition')
acewolfag_facenet_dataset_path = kagglehub.dataset_download('acewolfag/facenet-dataset')
acewolfag_endgame_path = kagglehub.dataset_download('acewolfag/endgame')
acewolfag_model_train_path = kagglehub.dataset_download('acewolfag/model-train')

print('Data source import complete.')

# %% [markdown]
# <a href="https://colab.research.google.com/github/acewolfag/black/blob/main/FaceNet_PyTourch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Face Recognition using Facenet and SVM with PCA Visualization
#
# The provided code implements a face recognition system using the [facenet-pytorch](https://www.kaggle.com/datasets/timesler/facenet-pytorch-vggface2) library and training using SVM Model. Here's a summary of the code:
#
# 1. Installation: The code installs the facenet-pytorch library from a local file using pip.
# 2. Model Checkpoints: The code copies the model checkpoints to the torch cache directory for automatic loading during runtime.
# 3. Importing Required Libraries: Necessary libraries and modules are imported for various functionalities, including image processing, machine learning, face detection, and feature extraction.
# 4. Helper Functions: Two helper functions are defined. The whitens function normalizes an input image tensor, and the extract_features function detects faces in an image and extracts their feature embeddings.
# 5. Device Configuration: The code sets the device to either GPU or CPU based on availability.
# 6. Model Initialization: The MTCNN and Inception ResNet V1 models are initialized with pre-trained weights. The models are moved to the selected device.
# 7. Dataset Preparation: The code defines the path to the dataset folder and creates ImageFolder datasets for the training and validation sets.
# 8. Embedding Extraction: The dataset_to_embeddings function is called to extract face embeddings from the training and validation sets.
# 9. Model Training: The train function is called to train the face recognition model using the extracted embeddings.
# 10. Model Saving: The trained model is serialized and saved as a pickle file.
# 11. Model Evaluation: The code generates a classification report and calculates the accuracy of the trained model using the embeddings from the training set.
# 12. Visualization: The code uses PCA to reduce the dimensionality of the embeddings and plots a 2D scatter plot of the embeddings with different colors representing different labels.
# 13. Image Testing: Random images from the validation set are selected and their predicted labels are compared with the true labels. The images, along with the predicted and actual labels, are displayed.
# 14. Single Image Testing: A single image is tested for face recognition, and the predicted label is displayed along with the image.

# %% [markdown]
# ## Importing Required Libraries
#
# The necessary libraries and modules are imported, including:

# %%
import os
import shutil
from sklearn.model_selection import train_test_split
path_folder = "/kaggle/input/facenet-dataset/Original Images"
# Đường dẫn gốc đến thư mục chứa dữ liệu
source_folder = path_folder
train_folder = "/kaggle/working/train"
val_folder = "/kaggle/working/val"

# Tạo thư mục train và val nếu chưa có
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)

# Lặp qua tất cả các folder (tương ứng với từng class)
for person in os.listdir(source_folder):
    person_path = os.path.join(source_folder, person)

    # Kiểm tra nếu đó là một folder
    if os.path.isdir(person_path):
        # Lấy danh sách các file trong folder person
        images = os.listdir(person_path)

        # Chia dữ liệu theo tỷ lệ train và val
        train_images, val_images = train_test_split(images, test_size=0.2, random_state=42)

        # Tạo thư mục cho class trong train và val
        train_class_folder = os.path.join(train_folder, person)
        val_class_folder = os.path.join(val_folder, person)
        os.makedirs(train_class_folder, exist_ok=True)
        os.makedirs(val_class_folder, exist_ok=True)

        # Di chuyển file vào thư mục tương ứng
        for image in train_images:
            shutil.copy(os.path.join(person_path, image), os.path.join(train_class_folder, image))

        for image in val_images:
            shutil.copy(os.path.join(person_path, image), os.path.join(val_class_folder, image))

        print(f"Đã hoàn thành phân chia cho class {person}")

print("Đã hoàn tất phân chia dữ liệu!")
# Out:
# Đã hoàn thành phân chia cho class Alia Bhatt
# Đã hoàn thành phân chia cho class Charlize Theron
# Đã hoàn thành phân chia cho class Zac Efron
# Đã hoàn thành phân chia cho class Billie Eilish
# Đã hoàn thành phân chia cho class Jessica Alba
# Đã hoàn thành phân chia cho class Priyanka Chopra
# Đã hoàn thành phân chia cho class Natalie Portman
# Đã hoàn thành phân chia cho class Hrithik Roshan
# Đã hoàn thành phân chia cho class Tom Cruise
# Đã hoàn thành phân chia cho class Roger Federer
# Đã hoàn thành phân chia cho class Henry Cavill
# Đã hoàn thành phân chia cho class Amitabh Bachchan
# Đã hoàn thành phân chia cho class Brad Pitt
# Đã hoàn thành phân chia cho class Dwayne Johnson
# Đã hoàn thành phân chia cho class Kashyap
# Đã hoàn thành phân chia cho class Elizabeth Olsen
# Đã hoàn thành phân chia cho class Camila Cabello
# Đã hoàn thành phân chia cho class Vijay Deverakonda
# Đã hoàn thành phân chia cho class Courtney Cox
# Đã hoàn thành phân chia cho class Ellen Degeneres
# Đã hoàn thành phân chia cho class Margot Robbie
# Đã hoàn thành phân chia cho class Anushka Sharma
# Đã hoàn thành phân chia cho class Lisa Kudrow
# Đã hoàn thành phân chia cho class Marmik
# Đã hoàn thành phân chia cho class Robert Downey Jr
# Đã hoàn thành phân chia cho class Virat Kohli
# Đã hoàn thành phân chia cho class Claire Holt
# Đã hoàn thành phân chia cho class Andy Samberg
# Đã hoàn thành phân chia cho class Alexandra Daddario
# Đã hoàn thành phân chia cho class Akshay Kumar
# Đã hoàn thành phân chia cho class Hugh Jackman
# Đã hoàn tất phân chia dữ liệu!

# %%
# !pip install facenet-pytorch
# Out:
# Collecting facenet-pytorch
#   Downloading facenet_pytorch-2.6.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.24.0 in /opt/conda/lib/python3.10/site-packages (from facenet-pytorch) (1.26.4)
# Collecting Pillow<10.3.0,>=10.2.0 (from facenet-pytorch)
#   Downloading pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from facenet-pytorch) (2.32.3)
# Collecting torch<2.3.0,>=2.2.0 (from facenet-pytorch)
#   Downloading torch-2.2.2-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchvision<0.18.0,>=0.17.0 (from facenet-pytorch)
#   Downloading torchvision-0.17.2-cp310-cp310-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from facenet-pytorch) (4.66.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (2024.8.30)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch<2.3.0,>=2.2.0->facenet-pytorch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch<2.3.0,>=2.2.0->facenet-pytorch)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch<2.3.0,>=2.2.0->facenet-pytorch)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch<2.3.0,>=2.2.0->facenet-pytorch)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch<2.3.0,>=2.2.0->facenet-pytorch)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch<2.3.0,>=2.2.0->facenet-pytorch)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch<2.3.0,>=2.2.0->facenet-pytorch)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch<2.3.0,>=2.2.0->facenet-pytorch)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch<2.3.0,>=2.2.0->facenet-pytorch)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch<2.3.0,>=2.2.0->facenet-pytorch)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch<2.3.0,>=2.2.0->facenet-pytorch)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.2.0 (from torch<2.3.0,>=2.2.0->facenet-pytorch)
#   Downloading triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch<2.3.0,>=2.2.0->facenet-pytorch)
#   Downloading nvidia_nvjitlink_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch<2.3.0,>=2.2.0->facenet-pytorch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch<2.3.0,>=2.2.0->facenet-pytorch) (1.3.0)
# Downloading facenet_pytorch-2.6.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 25.1 MB/s eta 0:00:0000:0100:01
# Downloading pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 89.1 MB/s eta 0:00:00:00:01
# Downloading torch-2.2.2-cp310-cp310-manylinux1_x86_64.whl (755.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 2.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 84.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 70.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 42.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 2.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 8.4 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 13.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 8.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 8.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 5.4 MB/s eta 0:00:00
# Downloading triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 9.7 MB/s eta 0:00:00:00:0100:01
# Downloading torchvision-0.17.2-cp310-cp310-manylinux1_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 89.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 74.7 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: triton, Pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision, facenet-pytorch
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 10.3.0
#     Uninstalling pillow-10.3.0:
#       Successfully uninstalled pillow-10.3.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.0
#     Uninstalling torch-2.4.0:
#       Successfully uninstalled torch-2.4.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.19.0
#     Uninstalling torchvision-0.19.0:
#       Successfully uninstalled torchvision-0.19.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.10.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.
# Successfully installed Pillow-10.2.0 facenet-pytorch-2.6.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.6.77 nvidia-nvtx-cu12-12.1.105 torch-2.2.2 torchvision-0.17.2 triton-2.2.0

# %%
import os
import argparse
import joblib
import numpy as np
from PIL import Image
from torchvision import transforms, datasets
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.metrics import accuracy_score
import joblib
import random
import matplotlib.pyplot as plt
from facenet_pytorch import MTCNN, InceptionResnetV1, extract_face
import torch
from sklearn.decomposition import PCA
from sklearn import svm

# %% [markdown]
# ## Utility Functions
#
# The following utility functions are defined:
#
# * **whitens(img):** Performs image whitening by subtracting the mean and dividing by the standard deviation of the image.
# * **extract_features(mtcnn, facenet, img):** Extracts facial features from an image using the MTCNN face detection and the InceptionResnetV1 model. Returns the bounding boxes and embeddings of detected faces.
# * **dataset_to_embeddings(dataset, mtcnn, facenet):** Converts a dataset of images into a list of embeddings and labels using the MTCNN and InceptionResnetV1 models.
# * **train(embeddings, labels):** Train the embeddings and labels using SVM Model with True probability

# %%
import torch
import numpy as np
from torchvision import transforms
from PIL import Image
from sklearn import svm

# Adjusted whitens function to maintain device consistency
def whitens(img):
    mean = img.mean()
    std = img.std()
    std_adj = std.clamp(min=1.0 / (float(img.numel()) ** 0.5))
    y = (img - mean) / std_adj
    return y

def extract_features(mtcnn, facenet, img, device='cuda'):
    img = img.to(device)
    img = transforms.ToPILImage()(img.squeeze_(0))
    bbs, _ = mtcnn.detect(img)
    if bbs is None:
        # If no face is detected
        return None, None

    # Move detected faces to the specified device
    faces = torch.stack([extract_face(img, bb) for bb in bbs]).to(device)
    whitened_faces = whitens(faces).to(device)  # Ensure whitening result is on the same device
    embeddings = facenet(whitened_faces).detach().cpu().numpy()  # Move to CPU for numpy conversion

    return bbs, embeddings

def dataset_to_embeddings(dataset, mtcnn, facenet, device='cuda'):
    transform = transforms.Compose([
        transforms.Resize(1024),
        transforms.ToTensor()
    ])

    embeddings = []
    labels = []
    for img_path, label in dataset.samples:
        print(img_path)

        img = transform(Image.open(img_path).convert('RGB')).unsqueeze_(0)
        _, embedding = extract_features(mtcnn, facenet, img, device=device)

        if embedding is None:
            print("Could not find face on {}".format(img_path))
            continue
        if embedding.shape[0] > 1:
            print("Multiple faces detected for {}, taking one with highest probability".format(img_path))
            embedding = embedding[0, :]
        embeddings.append(embedding.flatten())
        labels.append(label)

    return np.stack(embeddings), labels

def train(embeddings, labels):
    clf = svm.SVC(probability=True)
    clf.fit(embeddings, labels)
    return clf

# %% [markdown]
# ## Model Initialization
# The code initializes the MTCNN and InceptionResnetV1 models for face detection and feature extraction, respectively:

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

mtcnn = MTCNN(keep_all=True, thresholds=[0.6, 0.7, 0.9], device=device)
facenet = InceptionResnetV1(pretrained='vggface2').eval()

facenet = facenet.to(device)

# %% [markdown]
# ## Dataset Preparation
# The code defines the path to the dataset folder and creates ImageFolder datasets for training and validation:

# %%
data_path = path_folder
train_path = "/kaggle/working/train"
val_path = "/kaggle/working/val"

dataset_train = datasets.ImageFolder(root=train_path)
dataset_val = datasets.ImageFolder(root=val_path)

# %% [markdown]
# ## Generating Embeddings
# The code generates embeddings and labels for the training and validation datasets using the dataset_to_embeddings function:

# %%
X_train, y_train = dataset_to_embeddings(dataset_train, mtcnn, facenet)
X_test, y_test = dataset_to_embeddings(dataset_val, mtcnn, facenet)

X_train_class_idx = dataset_train.class_to_idx
X_test_class_idx = dataset_val.class_to_idx

embeddings, labels, class_to_idx = X_train, y_train, X_train_class_idx
# Out:
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_0.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_1.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_10.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_11.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_12.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_15.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_16.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_17.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_18.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_2.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_20.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_23.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_24.jpg
# Multiple faces detected for /kaggle/working/train/Akshay Kumar/Akshay Kumar_24.jpg, taking one with highest probability
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_25.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_26.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_28.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_29.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_3.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_31.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_32.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_33.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_34.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_36.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_37.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_38.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_39.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_4.jpg
# Multiple faces detected for /kaggle/working/train/Akshay Kumar/Akshay Kumar_4.jpg, taking one with highest probability
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_40.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_41.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_42.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_43.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_44.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_46.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_47.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_48.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_5.jpg
# Multiple faces detected for /kaggle/working/train/Akshay Kumar/Akshay Kumar_5.jpg, taking one with highest probability
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_6.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_7.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_8.jpg
# /kaggle/working/train/Akshay Kumar/Akshay Kumar_9.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_0.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_1.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_10.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_11.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_12.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_14.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_15.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_16.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_17.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_18.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_20.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_21.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_22.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_24.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_25.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_26.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_27.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_29.jpg
# Multiple faces detected for /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_29.jpg, taking one with highest probability
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_3.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_30.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_31.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_32.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_33.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_34.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_35.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_37.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_38.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_39.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_4.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_40.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_41.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_42.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_43.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_44.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario_48.jpg
# /kaggle/working/train/Alexandra Daddario/Alexandra Daddario
jpg
# /kaggle/working/train/Brad Pitt/Brad Pitt_77.jpg
# /kaggle/working/train/Brad Pitt/Brad Pitt_78.jpg
# /kaggle/working/train/Brad Pitt/Brad Pitt_79.jpg
# /kaggle/working/train/Brad Pitt/Brad Pitt_8.jpg
# /kaggle/working/train/Brad Pitt/Brad Pitt_80.jpg
# /kaggle/working/train/Brad Pitt/Brad Pitt_81.jpg
# /kaggle/working/train/Brad Pitt/Brad Pitt_82.jpg
# Multiple faces detected for /kaggle/working/train/Brad Pitt/Brad Pitt_82.jpg, taking one with highest probability
# /kaggle/working/train/Brad Pitt/Brad Pitt_84.jpg
# /kaggle/working/train/Brad Pitt/Brad Pitt_85.jpg
# /kaggle/working/train/Brad Pitt/Brad Pitt_86.jpg
# /kaggle/working/train/Brad Pitt/Brad Pitt_88.jpg
# /kaggle/working/train/Brad Pitt/Brad Pitt_9.jpg
# /kaggle/working/train/Brad Pitt/Brad Pitt_90.jpg
# /kaggle/working/train/Brad Pitt/Brad Pitt_92.jpg
# /kaggle/working/train/Brad Pitt/Brad Pitt_94.jpg
# /kaggle/working/train/Brad Pitt/Brad Pitt_95.jpg
# /kaggle/working/train/Brad Pitt/Brad Pitt_96.jpg
# /kaggle/working/train/Brad Pitt/Brad Pitt_97.jpg
# /kaggle/working/train/Brad Pitt/Brad Pitt_98.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_0.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_1.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_10.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_11.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_12.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_13.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_14.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_15.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_16.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_17.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_19.jpg
# Multiple faces detected for /kaggle/working/train/Camila Cabello/Camila Cabello_19.jpg, taking one with highest probability
# /kaggle/working/train/Camila Cabello/Camila Cabello_20.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_21.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_23.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_24.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_27.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_28.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_3.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_30.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_31.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_32.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_33.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_34.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_35.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_37.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_38.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_39.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_4.jpg
# Multiple faces detected for /kaggle/working/train/Camila Cabello/Camila Cabello_4.jpg, taking one with highest probability
# /kaggle/working/train/Camila Cabello/Camila Cabello_40.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_43.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_44.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_45.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_46.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_47.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_48.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_49.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_5.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_50.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_51.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_52.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_53.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_54.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_55.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_56.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_58.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_59.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_60.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_61.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_62.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_64.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_65.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_66.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_7.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_71.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_72.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_73.jpg
# Multiple faces detected for /kaggle/working/train/Camila Cabello/Camila Cabello_73.jpg, taking one with highest probability
# /kaggle/working/train/Camila Cabello/Camila Cabello_74.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_75.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_77.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_78.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_79.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_80.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_81.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_82.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_83.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_84.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_85.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_86.jpg
# /kaggle/working/train/Camila Cabello/Camila Cabello_9.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_0.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_1.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_10.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_11.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_12.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_14.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_15.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_16.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_17.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_18.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_2.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_21.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_23.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_25.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_26.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_27.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_28.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_29.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_3.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_30.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_31.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_32.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_33.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_34.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_35.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_36.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_38.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_39.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_4.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_40.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_41.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_42.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_43.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_44.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_45.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_46.jpg
# Multiple faces detected for /kaggle/working/train/Charlize Theron/Charlize Theron_46.jpg, taking one with highest probability
# /kaggle/working/train/Charlize Theron/Charlize Theron_47.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_48.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_49.jpg
# Multiple faces detected for /kaggle/working/train/Charlize Theron/Charlize Theron_49.jpg, taking one with highest probability
# /kaggle/working/train/Charlize Theron/Charlize Theron_5.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_51.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_52.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_53.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_54.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_55.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_57.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_59.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_6.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_60.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_61.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_62.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_63.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_64.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_65.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_69.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_7.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_70.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_72.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_74.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_75.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_76.jpg
# /kaggle/working/train/Charlize Theron/Charlize Theron_9.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_0.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_1.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_10.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_11.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_12.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_17.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_18.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_2.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_20.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_22.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_23.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_25.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_26.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_27.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_30.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_31.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_32.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_33.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_35.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_36.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_37.jpg
# Multiple faces detected for /kaggle/working/train/Claire Holt/Claire Holt_37.jpg, taking one with highest probability
# /kaggle/working/train/Claire Holt/Claire Holt_38.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_39.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_40.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_41.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_42.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_43.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_44.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_45.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_46.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_48.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_49.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_5.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_50.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_51.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_52.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_54.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_55.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_56.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_57.jpg
# Multiple faces detected for /kaggle/working/train/Claire Holt/Claire Holt_57.jpg, taking one with highest probability
# /kaggle/working/train/Claire Holt/Claire Holt_58.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_59.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_60.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_61.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_62.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_63.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_64.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_65.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_66.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_67.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_68.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_69.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_7.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_70.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_71.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_72.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_74.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_75.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_76.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_78.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_8.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_80.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_81.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_82.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_83.jpg
# Multiple faces detected for /kaggle/working/train/Claire Holt/Claire Holt_83.jpg, taking one with highest probability
# /kaggle/working/train/Claire Holt/Claire Holt_85.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_87.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_88.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_89.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_9.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_90.jpg
# Multiple faces detected for /kaggle/working/train/Claire Holt/Claire Holt_90.jpg, taking one with highest probability
# /kaggle/working/train/Claire Holt/Claire Holt_91.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_92.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_93.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_94.jpg
# /kaggle/working/train/Claire Holt/Claire Holt_95.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_0.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_10.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_12.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_16.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_17.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_18.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_19.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_2.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_21.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_22.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_23.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_25.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_26.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_27.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_28.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_29.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_3.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_31.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_33.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_34.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_35.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_36.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_37.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_38.jpg
# /kaggle/working/train/Courtney Cox/Courtney Cox_39.jpg
# ...
# /kaggle/working/val/Andy Samberg/Andy Samberg_41.jpg
# /kaggle/working/val/Andy Samberg/Andy Samberg_43.jpg
# /kaggle/working/val/Andy Samberg/Andy Samberg_44.jpg
# /kaggle/working/val/Andy Samberg/Andy Samberg_47.jpg
# /kaggle/working/val/Andy Samberg/Andy Samberg_55.jpg
# /kaggle/working/val/Andy Samberg/Andy Samberg_59.jpg
# /kaggle/working/val/Andy Samberg/Andy Samberg_64.jpg
# /kaggle/working/val/Andy Samberg/Andy Samberg_65.jpg
# /kaggle/working/val/Andy Samberg/Andy Samberg_73.jpg
# /kaggle/working/val/Andy Samberg/Andy Samberg_75.jpg
# /kaggle/working/val/Andy Samberg/Andy Samberg_76.jpg
# /kaggle/working/val/Andy Samberg/Andy Samberg_83.jpg
# /kaggle/working/val/Andy Samberg/Andy Samberg_84.jpg
# /kaggle/working/val/Andy Samberg/Andy Samberg_85.jpg
# /kaggle/working/val/Andy Samberg/Andy Samberg_86.jpg
# /kaggle/working/val/Anushka Sharma/Anushka Sharma_1.jpg
# /kaggle/working/val/Anushka Sharma/Anushka Sharma_18.jpg
# /kaggle/working/val/Anushka Sharma/Anushka Sharma_19.jpg
# /kaggle/working/val/Anushka Sharma/Anushka Sharma_2.jpg
# /kaggle/working/val/Anushka Sharma/Anushka Sharma_27.jpg
# /kaggle/working/val/Anushka Sharma/Anushka Sharma_34.jpg
# /kaggle/working/val/Anushka Sharma/Anushka Sharma_46.jpg
# /kaggle/working/val/Anushka Sharma/Anushka Sharma_50.jpg
# /kaggle/working/val/Anushka Sharma/Anushka Sharma_53.jpg
# /kaggle/working/val/Anushka Sharma/Anushka Sharma_55.jpg
# /kaggle/working/val/Anushka Sharma/Anushka Sharma_58.jpg
# Multiple faces detected for /kaggle/working/val/Anushka Sharma/Anushka Sharma_58.jpg, taking one with highest probability
# /kaggle/working/val/Anushka Sharma/Anushka Sharma_6.jpg
# /kaggle/working/val/Anushka Sharma/Anushka Sharma_61.jpg
# /kaggle/working/val/Anushka Sharma/Anushka Sharma_8.jpg
# /kaggle/working/val/Billie Eilish/Billie Eilish_1.jpg
# /kaggle/working/val/Billie Eilish/Billie Eilish_15.jpg
# Multiple faces detected for /kaggle/working/val/Billie Eilish/Billie Eilish_15.jpg, taking one with highest probability
# /kaggle/working/val/Billie Eilish/Billie Eilish_17.jpg
# /kaggle/working/val/Billie Eilish/Billie Eilish_21.jpg
# /kaggle/working/val/Billie Eilish/Billie Eilish_23.jpg
# /kaggle/working/val/Billie Eilish/Billie Eilish_31.jpg
# Multiple faces detected for /kaggle/working/val/Billie Eilish/Billie Eilish_31.jpg, taking one with highest probability
# /kaggle/working/val/Billie Eilish/Billie Eilish_35.jpg
# /kaggle/working/val/Billie Eilish/Billie Eilish_38.jpg
# /kaggle/working/val/Billie Eilish/Billie Eilish_41.jpg
# /kaggle/working/val/Billie Eilish/Billie Eilish_57.jpg
# Multiple faces detected for /kaggle/working/val/Billie Eilish/Billie Eilish_57.jpg, taking one with highest probability
# /kaggle/working/val/Billie Eilish/Billie Eilish_63.jpg
# /kaggle/working/val/Billie Eilish/Billie Eilish_68.jpg
# /kaggle/working/val/Billie Eilish/Billie Eilish_7.jpg
# /kaggle/working/val/Billie Eilish/Billie Eilish_74.jpg
# /kaggle/working/val/Billie Eilish/Billie Eilish_77.jpg
# /kaggle/working/val/Billie Eilish/Billie Eilish_78.jpg
# /kaggle/working/val/Billie Eilish/Billie Eilish_80.jpg
# Multiple faces detected for /kaggle/working/val/Billie Eilish/Billie Eilish_80.jpg, taking one with highest probability
# /kaggle/working/val/Billie Eilish/Billie Eilish_84.jpg
# /kaggle/working/val/Billie Eilish/Billie Eilish_88.jpg
# /kaggle/working/val/Billie Eilish/Billie Eilish_90.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_109.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_110.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_114.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_118.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_19.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_22.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_23.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_29.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_33.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_41.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_52.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_56.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_58.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_60.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_62.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_64.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_70.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_73.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_83.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_87.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_89.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_91.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_93.jpg
# /kaggle/working/val/Brad Pitt/Brad Pitt_99.jpg
# /kaggle/working/val/Camila Cabello/Camila Cabello_18.jpg
# /kaggle/working/val/Camila Cabello/Camila Cabello_2.jpg
# /kaggle/working/val/Camila Cabello/Camila Cabello_22.jpg
# /kaggle/working/val/Camila Cabello/Camila Cabello_25.jpg
# /kaggle/working/val/Camila Cabello/Camila Cabello_26.jpg
# /kaggle/working/val/Camila Cabello/Camila Cabello_29.jpg
# /kaggle/working/val/Camila Cabello/Camila Cabello_36.jpg
# Multiple faces detected for /kaggle/working/val/Camila Cabello/Camila Cabello_36.jpg, taking one with highest probability
# /kaggle/working/val/Camila Cabello/Camila Cabello_41.jpg
# /kaggle/working/val/Camila Cabello/Camila Cabello_42.jpg
# /kaggle/working/val/Camila Cabello/Camila Cabello_57.jpg
# /kaggle/working/val/Camila Cabello/Camila Cabello_6.jpg
# /kaggle/working/val/Camila Cabello/Camila Cabello_63.jpg
# /kaggle/working/val/Camila Cabello/Camila Cabello_67.jpg
# /kaggle/working/val/Camila Cabello/Camila Cabello_68.jpg
# /kaggle/working/val/Camila Cabello/Camila Cabello_69.jpg
# /kaggle/working/val/Camila Cabello/Camila Cabello_70.jpg
# /kaggle/working/val/Camila Cabello/Camila Cabello_76.jpg
# /kaggle/working/val/Camila Cabello/Camila Cabello_8.jpg
# /kaggle/working/val/Charlize Theron/Charlize Theron_13.jpg
# /kaggle/working/val/Charlize Theron/Charlize Theron_19.jpg
# /kaggle/working/val/Charlize Theron/Charlize Theron_20.jpg
# /kaggle/working/val/Charlize Theron/Charlize Theron_22.jpg
# /kaggle/working/val/Charlize Theron/Charlize Theron_24.jpg
# /kaggle/working/val/Charlize Theron/Charlize Theron_37.jpg
# /kaggle/working/val/Charlize Theron/Charlize Theron_50.jpg
# /kaggle/working/val/Charlize Theron/Charlize Theron_56.jpg
# /kaggle/working/val/Charlize Theron/Charlize Theron_58.jpg
# /kaggle/working/val/Charlize Theron/Charlize Theron_66.jpg
# /kaggle/working/val/Charlize Theron/Charlize Theron_67.jpg
# /kaggle/working/val/Charlize Theron/Charlize Theron_68.jpg
# /kaggle/working/val/Charlize Theron/Charlize Theron_71.jpg
# /kaggle/working/val/Charlize Theron/Charlize Theron_73.jpg
# /kaggle/working/val/Charlize Theron/Charlize Theron_77.jpg
# /kaggle/working/val/Charlize Theron/Charlize Theron_8.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_13.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_14.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_15.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_16.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_19.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_21.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_24.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_28.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_29.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_3.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_34.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_4.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_47.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_53.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_6.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_73.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_77.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_79.jpg
# /kaggle/working/val/Claire Holt/Claire Holt_84.jpg
# Multiple faces detected for /kaggle/working/val/Claire Holt/Claire Holt_84.jpg, taking one with highest probability
# /kaggle/working/val/Claire Holt/Claire Holt_86.jpg
# /kaggle/working/val/Courtney Cox/Courtney Cox_1.jpg
# /kaggle/working/val/Courtney Cox/Courtney Cox_11.jpg
# /kaggle/working/val/Courtney Cox/Courtney Cox_13.jpg
# /kaggle/working/val/Courtney Cox/Courtney Cox_14.jpg
# Multiple faces detected for /kaggle/working/val/Courtney Cox/Courtney Cox_14.jpg, taking one with highest probability
# /kaggle/working/val/Courtney Cox/Courtney Cox_15.jpg
# /kaggle/working/val/Courtney Cox/Courtney Cox_20.jpg
# /kaggle/working/val/Courtney Cox/Courtney Cox_24.jpg
# /kaggle/working/val/Courtney Cox/Courtney Cox_30.jpg
# /kaggle/working/val/Courtney Cox/Courtney Cox_32.jpg
# /kaggle/working/val/Courtney Cox/Courtney Cox_45.jpg
# /kaggle/working/val/Courtney Cox/Courtney Cox_46.jpg
# /kaggle/working/val/Courtney Cox/Courtney Cox_47.jpg
# /kaggle/working/val/Courtney Cox/Courtney Cox_48.jpg
# /kaggle/working/val/Courtney Cox/Courtney Cox_54.jpg
# /kaggle/working/val/Courtney Cox/Courtney Cox_60.jpg
# /kaggle/working/val/Courtney Cox/Courtney Cox_67.jpg
# /kaggle/working/val/Dwayne Johnson/Dwayne Johnson_14.jpg
# /kaggle/working/val/Dwayne Johnson/Dwayne Johnson_19.jpg
# /kaggle/working/val/Dwayne Johnson/Dwayne Johnson_21.jpg
# /kaggle/working/val/Dwayne Johnson/Dwayne Johnson_26.jpg
# /kaggle/working/val/Dwayne Johnson/Dwayne Johnson_31.jpg
# /kaggle/working/val/Dwayne Johnson/Dwayne Johnson_33.jpg
# /kaggle/working/val/Dwayne Johnson/Dwayne Johnson_35.jpg
# /kaggle/working/val/Dwayne Johnson/Dwayne Johnson_39.jpg
# /kaggle/working/val/Dwayne Johnson/Dwayne Johnson_46.jpg
# /kaggle/working/val/Dwayne Johnson/Dwayne Johnson_48.jpg
# /kaggle/working/val/Dwayne Johnson/Dwayne Johnson_49.jpg
# /kaggle/working/val/Dwayne Johnson/Dwayne Johnson_60.jpg
# /kaggle/working/val/Dwayne Johnson/Dwayne Johnson_8.jpg
# /kaggle/working/val/Elizabeth Olsen/Elizabeth Olsen_10.jpg
# /kaggle/working/val/Elizabeth Olsen/Elizabeth Olsen_12.jpg
# /kaggle/working/val/Elizabeth Olsen/Elizabeth Olsen_18.jpg
# /kaggle/working/val/Elizabeth Olsen/Elizabeth Olsen_21.jpg
# /kaggle/working/val/Elizabeth Olsen/Elizabeth Olsen_22.jpg
# /kaggle/working/val/Elizabeth Olsen/Elizabeth Olsen_27.jpg
# /kaggle/working/val/Elizabeth Olsen/Elizabeth Olsen_3.jpg
# /kaggle/working/val/Elizabeth Olsen/Elizabeth Olsen_33.jpg
# /kaggle/working/val/Elizabeth Olsen/Elizabeth Olsen_47.jpg
# /kaggle/working/val/Elizabeth Olsen/Elizabeth Olsen_52.jpg
# /kaggle/working/val/Elizabeth Olsen/Elizabeth Olsen_58.jpg
# /kaggle/working/val/Elizabeth Olsen/Elizabeth Olsen_59.jpg
# /kaggle/working/val/Elizabeth Olsen/Elizabeth Olsen_6.jpg
# /kaggle/working/val/Elizabeth Olsen/Elizabeth Olsen_64.jpg
# /kaggle/working/val/Elizabeth Olsen/Elizabeth Olsen_7.jpg
# /kaggle/working/val/Ellen Degeneres/Ellen Degeneres_0.jpg
# /kaggle/working/val/Ellen Degeneres/Ellen Degeneres_10.jpg
# Multiple faces detected for /kaggle/working/val/Ellen Degeneres/Ellen Degeneres_10.jpg, taking one with highest probability
# /kaggle/working/val/Ellen Degeneres/Ellen Degeneres_12.jpg
# /kaggle/working/val/Ellen Degeneres/Ellen Degeneres_19.jpg
# /kaggle/working/val/Ellen Degeneres/Ellen Degeneres_22.jpg
# /kaggle/working/val/Ellen Degeneres/Ellen Degeneres_28.jpg
# Multiple faces detected for /kaggle/working/val/Ellen Degeneres/Ellen Degeneres_28.jpg, taking one with highest probability
# /kaggle/working/val/Ellen Degeneres/Ellen Degeneres_3.jpg
# /kaggle/working/val/Ellen Degeneres/Ellen Degeneres_34.jpg
# /kaggle/working/val/Ellen Degeneres/Ellen Degeneres_36.jpg
# /kaggle/working/val/Ellen Degeneres/Ellen Degeneres_4.jpg
# /kaggle/working/val/Ellen Degeneres/Ellen Degeneres_46.jpg
# /kaggle/working/val/Ellen Degeneres/Ellen Degeneres_51.jpg
# /kaggle/working/val/Ellen Degeneres/Ellen Degeneres_58.jpg
# /kaggle/working/val/Ellen Degeneres/Ellen Degeneres_59.jpg
# /kaggle/working/val/Ellen Degeneres/Ellen Degeneres_66.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_1.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_104.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_12.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_15.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_2.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_37.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_4.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_43.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_51.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_52.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_54.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_61.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_62.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_66.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_7.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_71.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_72.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_75.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_85.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_86.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_9.jpg
# /kaggle/working/val/Henry Cavill/Henry Cavill_91.jpg
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_100.jpg
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_14.jpg
# Multiple faces detected for /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_14.jpg, taking one with highest probability
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_17.jpg
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_29.jpg
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_32.jpg
# Multiple faces detected for /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_32.jpg, taking one with highest probability
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_40.jpg
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_43.jpg
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_45.jpg
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_47.jpg
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_50.jpg
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_51.jpg
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_61.jpg
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_63.jpg
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_66.jpg
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_71.jpg
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_81.jpg
# Multiple faces detected for /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_81.jpg, taking one with highest probability
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_86.jpg
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_88.jpg
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_9.jpg
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_95.jpg
# Multiple faces detected for /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_95.jpg, taking one with highest probability
# /kaggle/working/val/Hrithik Roshan/Hrithik Roshan_97.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_0.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_108.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_109.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_17.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_2.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_20.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_24.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_33.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_36.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_37.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_40.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_45.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_5.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_51.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_56.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_72.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_74.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_76.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_88.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_89.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_91.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_96.jpg
# /kaggle/working/val/Hugh Jackman/Hugh Jackman_97.jpg
# /kaggle/working/val/Jessica Alba/Jessica Alba_10.jpg
# /kaggle/working/val/Jessica Alba/Jessica Alba_102.jpg
# /kaggle/working/val/Jessica Alba/Jessica Alba_104.jpg
# /kaggle/working/val/Jessica Alba/Jessica Alba_14.jpg
# /kaggle/working/val/Jessica Alba/Jessica Alba_16.jpg
# /kaggle/working/val/Jessica Alba/Jessica Alba_19.jpg
# Multiple faces detected for /kaggle/working/val/Jessica Alba/Jessica Alba_19.jpg, taking one with highest probability
# /kaggle/working/val/Jessica Alba/Jessica Alba_2.jpg
# /kaggle/working/val/Jessica Alba/Jessica Alba_26.jpg

# %% [markdown]
# ## Training
# The code trains a classification model using the training embeddings and labels:

# %%
clf = train(embeddings, labels)

import json
import numpy as np

# Kiểm tra và chuyển đổi từng biến nếu là ndarray
data = {
    "embeddings": embeddings.tolist() if isinstance(embeddings, np.ndarray) else embeddings,
    "labels": labels.tolist() if isinstance(labels, np.ndarray) else labels,
    "class_to_idx": class_to_idx.tolist() if isinstance(class_to_idx, np.ndarray) else class_to_idx
}

# Lưu dữ liệu vào file .txt
file_path = 'data.txt'
with open(file_path, 'w', encoding='utf-8') as file:
    json.dump(data, file)
print("Dữ liệu đã được lưu thành công vào", file_path)

# Save the trained model
joblib.dump(clf, 'face_recognition_model.pkl')

# %% [markdown]
# ## Model Evaluation
# The code evaluates the trained model by printing a classification report and calculating the accuracy on the validation set:

# %%
idx_to_class = {v: k for k, v in class_to_idx.items()}
print(idx_to_class)

target_names = list(map(lambda i: i[1], sorted(idx_to_class.items(), key=lambda i: i[0])))
print(metrics.classification_report(labels, clf.predict(embeddings), target_names=target_names))

# Predict labels for validation set and calculate accuracy
y_val_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_val_pred)
print('Validation Accuracy: {:.2f}%'.format(accuracy*100))

# %% [markdown]
# ## Visualization
# The code visualizes the embeddings in a 2D space using PCA and plots a scatter plot with colored points representing different classes:

# %%
import os
import random
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Tạo màu ngẫu nhiên
def generate_random_color():
    """Hàm tạo màu ngẫu nhiên dưới dạng ký tự của matplotlib"""
    return "#{:06x}".format(random.randint(0, 0xFFFFFF))

# Gán màu ngẫu nhiên cho từng class trong thư mục dữ liệu
def assign_colors(data_folder):
    """
    Gán màu ngẫu nhiên cho từng class trong thư mục dữ liệu.
    Trả về dictionary với class làm key và màu sắc làm giá trị.
    """
    class_labels = [d for d in os.listdir(data_folder) if os.path.isdir(os.path.join(data_folder, d))]
    colors = {label: generate_random_color() for label in class_labels}
    return colors

# Thư mục dữ liệu của bạn
data_folder = path_folder
color_mapping = assign_colors(data_folder)

# In ra kết quả gán màu
for label, color in color_mapping.items():
    print(f"'{label}' : '{color}',")

# Thực hiện PCA để giảm chiều của embeddings (giả sử X_train và y_train đã có sẵn)
pca = PCA(n_components=2)  # Giảm xuống 2 chiều để vẽ biểu đồ
embeddings_2d = pca.fit_transform(X_train)

# Gán nhãn từ số sang tên (giả sử idx_to_class đã có sẵn)
mapped_labels = [idx_to_class[label] for label in y_train]

# Sử dụng dictionary color_mapping để lấy màu sắc cho từng nhãn
def assign_colors(label):
    return color_mapping.get(label, "#000000")  # Mặc định màu đen nếu nhãn không có trong color_mapping

# Tạo mảng màu cho tất cả các điểm
colors = list(map(assign_colors, mapped_labels))

# Vẽ biểu đồ tán xạ với embeddings 2D
plt.scatter(embeddings_2d[:, 0], embeddings_2d[:, 1], c=colors)
plt.xlabel("PCA Dimension 1")
plt.ylabel("PCA Dimension 2")
plt.title("Visualization of Embeddings with PCA")
plt.show()

# %% [markdown]
# ## Face Recognition
#
# The code performs face recognition on randomly selected images from the validation set. It predicts the labels for the images and displays the predicted and actual labels along with the image:

# %%
transform_img = transforms.Compose([transforms.Resize(1024)])
transform = transforms.Compose([
        transforms.Resize(1024),
        transforms.ToTensor()
    ])



dataset_val = datasets.ImageFolder(root="/kaggle/working/val")
val_samples = dataset_val.samples


random_samples = random.choices(val_samples, k=5)

for img_path, true_label in random_samples:

    img_ = transform_img(Image.open(img_path).convert('RGB'))
    img = transform(Image.open(img_path).convert('RGB'))

    # Extract features
    _, embedding = extract_features(mtcnn, facenet, img)
    if embedding is None:
        print("Could not find face on {}".format(img_path))
        continue
    if embedding.shape[0] > 1:
        print("Multiple faces detected for {}, taking one with highest probability".format(img_path))
        embedding = embedding[0, :]


    predicted_label = clf.predict(embedding.reshape(1, -1))
    print(clf.predict_proba(embedding))

    predicted_class = idx_to_class[predicted_label[0]]
    true_class = idx_to_class[true_label]

    plt.imshow(img_)
    plt.title(f'Predicted: {predicted_class}, Actual: {true_class}')
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## Intruder Recognition
#
# The code performs face recognition on a single image specified by img_path and displays the predicted label along with the image:

# %%
import json
import numpy as np
import joblib

# Đường dẫn file
data_file_path = '/kaggle/input/model-train/data.txt'
model_file_path = '/kaggle/input/model-train/face_recognition_model.pkl'

# Tải lại dữ liệu
with open(data_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# Chuyển đổi lại các dữ liệu đã lưu
embeddings = np.array(data["embeddings"])
labels = np.array(data["labels"])
class_to_idx = data["class_to_idx"]

print("Dữ liệu đã được tải lại thành công từ", data_file_path)

# Tải model đã huấn luyện
clf = joblib.load(model_file_path)
print("Model đã được tải lại thành công từ", model_file_path)
transform_img = transforms.Compose([transforms.Resize(1024)])
transform = transforms.Compose([
        transforms.Resize(1024),
        transforms.ToTensor()
    ])

# %%
img_path = '/kaggle/input/avengers-face-recognition/cropped_images/robert_downey_jr/robert_downey_jr13.png'

img_ = transform_img(Image.open(img_path).convert('RGB'))
img = transform(Image.open(img_path).convert('RGB'))
_, embedding = extract_features(mtcnn, facenet, img)

predicted_label = clf.predict(embedding.reshape(1, -1))
# Convert label indexes back to original classes
predicted_class = idx_to_class[predicted_label[0]]
true_class = idx_to_class[true_label]
print((clf.predict_proba(embedding)))
thres = 0.6
if np.max(clf.predict_proba(embedding)) < thres:
    predicted_class = 'Intruder'


plt.imshow(img_)
plt.title(f'Predicted: {predicted_class}, Actual: {"TomCruise"}')
plt.axis('off')
plt.show()

# %%
# Đường dẫn đến video
video_path = '/kaggle/input/endgame/AVENGERS- ENDGAME All Movie Clips - Final Battle (2019).mp4'
output_video_path = '/kaggle/working/output_video.mp4'

import cv2
import torch
import numpy as np
from facenet_pytorch import MTCNN, InceptionResnetV1
from tqdm import tqdm

# Tải model InceptionResnetV1 đã huấn luyện sẵn và lớp MTCNN
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
mtcnn = MTCNN(keep_all=True, device=device)
facenet = InceptionResnetV1(pretrained='vggface2').eval().to(device)

# Kiểm tra xem video có mở được không
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print("Không thể mở video")
    exit()

# Lấy tổng số khung hình để thiết lập thanh tiến độ
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

# Thiết lập video writer để lưu video đầu ra
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, 20.0, (int(cap.get(3)), int(cap.get(4))))

# Tạo thanh tiến độ
pbar = tqdm(total=total_frames, desc="Processing video frames", position=0, leave=True)

# Đọc từng khung hình của video
for _ in range(total_frames):
    ret, frame = cap.read()
    if not ret:
        break

    # Chuyển từ BGR sang RGB vì OpenCV đọc ảnh theo BGR
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Phát hiện tất cả khuôn mặt trong khung hình
    boxes, _ = mtcnn.detect(frame_rgb)

    # Nếu phát hiện được ít nhất một khuôn mặt
    if boxes is not None:
        h, w, _ = frame.shape
        for box in boxes:
            x1, y1, x2, y2 = map(int, box)
            x1, y1, x2, y2 = max(0, x1), max(0, y1), min(w, x2), min(h, y2)
            cropped_face = frame_rgb[y1:y2, x1:x2]

            # Bỏ qua nếu khuôn mặt không hợp lệ
            if cropped_face.size == 0:
                continue

            # Chuẩn bị khuôn mặt cho dự đoán
            face = cv2.resize(cropped_face, (160, 160))
            face = torch.tensor(face).permute(2, 0, 1).float().div(255).unsqueeze(0).to(device)

            # Tạo embedding và dự đoán danh tính
            with torch.no_grad():
                embedding = facenet(face).cpu().numpy()
                predicted_label = clf.predict(embedding.reshape(1, -1))
                predicted_class = idx_to_class[predicted_label[0]]

                # Lấy xác suất dự đoán
                probabilities = clf.predict_proba(embedding)
                max_prob = np.max(probabilities)

                # Nếu độ tin cậy thấp hơn ngưỡng, gán nhãn là "Intruder"
                if max_prob < 0.6:
                    predicted_class = 'Intruder'

                # Vẽ khung và nhãn trên hình ảnh
                label = f"{predicted_class} ({max_prob * 100:.1f}%)"
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

    # Ghi khung hình đã xử lý vào video đầu ra
    out.write(cv2.cvtColor(frame, cv2.COLOR_RGB2BGR))

    # Cập nhật thanh tiến độ
    pbar.update(1)

# Đóng thanh tiến độ và giải phóng bộ nhớ
pbar.close()
cap.release()
out.release()
print("Video đã được xử lý và lưu thành công.")
